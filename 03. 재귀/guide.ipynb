# %% [markdown]
# # 재귀
#
# 재귀는 매우 머리가 복잡해지고 생각하기 어려운 문제이다.
#
# 특히 무한 츠쿠요미(무한 반복)에 빠지기 너무 쉽다.
#
# 이때문에 실무에서는 최대한 재귀를 사용하지 않고 해결하려는 경향이 강하다.
#
# 하지만 코딩 테스트를 위해서 익혀두자!
#
# #### 목차
#
# |문제|난이도|중요도|문제유형|내용|
# |---|---|---|---|-----|
# |팩토리얼2|★☆☆☆☆|★☆☆☆☆|DP|굳이 재귀로 풀어야 할까?|
# |피보나치 수 5|★★☆☆☆|★★★★☆|DP|재귀 보다는 DP(동적 프로그래밍)를 배우기 좋은 문제이다. 이 문제를 통해 DP와 재귀의 차이를 알고 언제 재귀를 쓸지 DP를 쓸지 생각해보자|
# |재귀의 귀재|★★★☆☆|★★☆☆☆|구현|C언어를 python으로 바꿀 수 있는지 묻는 문제. 재귀 보단 구현력을 요구하는 문제|
# |알고리즘 수업 - 병합 정렬 1|★★★☆☆|★★☆☆☆|구현|psudo코드를 python으로 바꿀 수 있는지 묻는문제. 재귀보단 구현력을 요구하는 문제|
# |칸토어 집합|★★☆☆☆|★★★★★|재귀함수|재귀의 가장 기본 꼴!! 꼭 풀어보자!!|
# |별찍기 - 10|★★★☆☆|★★★★★|재귀함수|재귀가 머리아픈 이유. n=3부터 생각하자|
# |하노이탑 이동 순서|★★★☆☆|★★★★★|재귀함수|재귀가 머리아픈 이유. 못 풀겠으면 problem.txt를 참고해서 규칙을 만들어보자.|

# %%
# 재귀 기본꼴 => 백트래킹의 template과 유사하다.

def recursion(n):
    # 무한 츠쿠요미를 막기위한 종료 조건
    if n == K:
        return

    recursion(n-1)
