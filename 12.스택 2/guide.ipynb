# %% [markdown]
# # 스택 2
#
#
# #### 목차
#
# |문제|난이도|중요도|문제유형|내용|
# |---|---|---|---|-----|
# |문자열 폭발|★★★☆☆|★★★☆☆|스택|삭제를 할 땐, 슬라이싱 보단 del을 애용하자!|
# |오큰수|★★★☆☆|★★★☆☆|스택|이중 반복문 보단 스택이 더 빠르긴 해... 제한시간을 보고 무엇을 사용할지 판단하자.(1초 => stack, 2초=> 이중반복)|
# |오등큰수|★★★☆☆|★★★☆☆|스택|from collections import Couter 기억하자!|
# |히스토그램|★★★★★|★★★★★|스택, 분할정복|분할정복 파트에서 나온 히스토그램 가장 큰 직사각형 문제와 동일하다.|
# |오아시스재결합|★★★★★|★★★★★|스택|오른쪽을 볼 수 있는 사람들을 놔두자... 같은 키 처리하는 것 머리 이쁘게 써야 해결가능...|
